# %% [markdown]
# # Dados Outubro 2003

# %%
import numpy as np
import glob
import matplotlib.pyplot as plt

# %%
#print glob.glob('vss200310[0-30]*dmin.min') #listagem de arquivos

# %% [markdown]
# * **Empilhando os valores listados por minuto para todos os dias do mês**

# %%
filenames = glob.glob('vss200310*dmin.min')    


for f in filenames:                    
    
    data = np.loadtxt(fname=f, skiprows=26, usecols= (3,4,5,6))
    
    if f == filenames[0]:
        h_out = data[:,0]
        f_out = data[:,3]
        
    else:
        h = data[:,0]
        h_out = np.hstack((h_out,h))
        f = data[:,3]
        f_out = np.hstack((f_out,f))
        
#print h_out
#print f_out

h_out[h_out > 60000] = np.nan 
#print h_out

f_out[f_out > 60000] = np.nan 
#print f_out

# %% [markdown]
# * **Plot para a componente H(nT) em Outubro de 2003**

# %%
d = h_out           
N = h_out.shape[0]
time = range(0,N)

fig = plt.figure(figsize=(15.0, 5.0))

H = plt.plot(time, d)

plt.xticks([d*1440 for d in range(31)], [d+1 for d in range(31)])

plt.ylabel('H(nT)')
plt.xlabel('Day')
plt.show()

# %% [markdown]
# * **Plot para a componente F(nT) em Outubro de 2003**

# %%
d = f_out           
N = f_out.shape[0]
time = range(0,N)

fig = plt.figure(figsize=(15.0, 5.0))

F = plt.plot(time, d)

plt.xticks([d*1440 for d in range(31)], [d+1 for d in range(31)])

plt.axhline(y= 23100, linewidth=1, color='grey')
plt.axhline(y= 23200, linewidth=1, color='grey')
plt.axhline(y= 23300, linewidth=1, color='grey')
plt.axhline(y= 23400, linewidth=1, color='grey')
plt.axhline(y= 23500, linewidth=1, color='grey')

plt.ylabel('F(nT)')
plt.xlabel('Day')
plt.show()

# %% [markdown]
# * **Selecionado o range entre os dias 27 e 31 de outubro**
# >Para a componente H

# %%
d = h_out[37440:44640]
N = h_out.shape[0]
time = range(37440,44640)

fig = plt.figure(figsize=(15.0, 10.0))

H = plt.plot(time, d)

plt.xticks([dia*1440 for dia in range(26,32)], ['%i/06/2013'%dia for dia in range(27,32)])

plt.title('H(nT) Component From 27 to 31 October 2003')
plt.ylabel('H(nT)')
plt.xlabel('Day')
plt.savefig('H27_31_october(2003).png')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-df417c418801> in <module>()
#       1
# ----> 2 d = h_out[37440:44640]
#       3 N = h_out.shape[0]
#       4 time = range(37440,44640)
#       5
#
# NameError: name 'h_out' is not defined

# %% [markdown]
# >Para a componente F

# %%
d = f_out[37440:40320]
e = f_out[40320:44640]
N = f_out.shape[0]
time = range(37440,44640)

# %%
fig = plt.figure(figsize=(15.0, 10.0))

sq = plt.plot(time, d)
#B = plt.plot(time, e,label="IGRF", linestyle='solid', color='red', linewidth=2)

plt.xticks([dia*1440 for dia in range(26,32)], ['%i/06/2013'%dia for dia in range(27,32)])

plt.title('Magnetic Field F(nT) From 27 to 31 October 2003')
plt.ylabel('F(nT)')
plt.xlabel('Day')
plt.savefig('F27_31_october(2003).png')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-ffc4a6664037> in <module>()
#       4 fig = plt.figure(figsize=(15.0, 10.0))
#       5
# ----> 6 sq = plt.plot(time1, d)
#       7 #B = plt.plot(time, e,label="IGRF", linestyle='solid', color='red', linewidth=2)
#       8
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(*args, **kwargs)
#    3315                       mplDeprecation)
#    3316     try:
# -> 3317         ret = ax.plot(*args, **kwargs)
#    3318     finally:
#    3319         ax._hold = washold
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1895                     warnings.warn(msg % (label_namer, func.__name__),
#    1896                                   RuntimeWarning, stacklevel=2)
# -> 1897             return func(ax, *args, **kwargs)
#    1898         pre_doc = inner.__doc__
#    1899         if pre_doc is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, *args, **kwargs)
#    1404         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1405
# -> 1406         for line in self._get_lines(*args, **kwargs):
#    1407             self.add_line(line)
#    1408             lines.append(line)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _grab_next_args(self, *args, **kwargs)
#     405                 return
#     406             if len(remaining) <= 3:
# --> 407                 for seg in self._plot_args(remaining, kwargs):
#     408                     yield seg
#     409                 return
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     383             x, y = index_of(tup[-1])
#     384
# --> 385         x, y = self._xy_from_xy(x, y)
#     386
#     387         if self.command == 'plot':
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _xy_from_xy(self, x, y)
#     242         if x.shape[0] != y.shape[0]:
#     243             raise ValueError("x and y must have same first dimension, but "
# --> 244                              "have shapes {} and {}".format(x.shape, y.shape))
#     245         if x.ndim > 2 or y.ndim > 2:
#     246             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (7200,) and (2880,)

# %%
1440*25
# Out:
# 36000
